# %% [markdown]
# # Paper Reproduction

# %% [markdown]
# ## 1. Environment Setting

# %%
import os
print (os.getcwd())
# Out:
# /home/data/vip8t02/Project/PanMyeloid-assignment/report

# %%
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 0    # errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80)
sc.logging.print_versions()
# Out:
# scanpy==1.4.3 anndata==0.7.6 umap==0.5.1 numpy==1.21.2 scipy==1.7.1 pandas==1.3.3 scikit-learn==0.24.2 statsmodels==0.13.0 python-igraph==0.9.7

# %% [markdown]
# ## 2. Initialize Datasets

# %% [markdown]
# * Check data integrity

# %%
import os
import gzip

def check_integrity(local_file):
    if local_file.endswith('.gz'):
        with gzip.open(local_file, 'rb') as f:
            try:
                f.seek(-1, os.SEEK_END)
            except:
                return -1
    return 0

check_integrity("../rawData/LYM/GSE154763_LYM_normalized_expression.csv.gz")
# Out:
# 0

# %% [markdown]
# ### 2.1 Create Scanpy Object

# %%
LYM = pd.read_csv("../rawData/LYM/GSE154763_LYM_normalized_expression.csv.gz", index_col=0)
LYM.meta = pd.read_csv("../rawData/LYM/GSE154763_LYM_metadata.csv.gz", index_col=0)

cellinfo = pd.DataFrame(LYM.index,index=LYM.index,columns=['sample_index'])
geneinfo = pd.DataFrame(LYM.columns,index=LYM.columns,columns=['genes_index'])
LYM_ann = sc.AnnData(LYM, obs=cellinfo, var = geneinfo)
LYM_ann
# Out:
# AnnData object with n_obs × n_vars = 615 × 11283
#     obs: 'sample_index'
#     var: 'genes_index'

# %%
LYM_ann.var.head()
# Out:
#            genes_index
# FO538757.2  FO538757.2
# LINC00115    LINC00115
# NOC2L            NOC2L
# HES4              HES4
# ISG15            ISG15

# %%
sc.pp.highly_variable_genes(LYM_ann, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(LYM_ann)
